# %%
import findspark

# %%
findspark.init()

# %%
findspark.find()
# Out:
# '/opt/spark'

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Exploration").master("local[3]").getOrCreate()
# Out:
# 25/03/24 22:44:20 WARN Utils: Your hostname, luffy-Latitude-3400 resolves to a loopback address: 127.0.1.1; using 192.168.1.9 instead (on interface wlp0s20f3)
# 25/03/24 22:44:20 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/03/24 22:44:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 58134)
# Traceback (most recent call last):
#   File "/home/luffy/anaconda3/envs/spark/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/luffy/anaconda3/envs/spark/lib/python3.12/socketserver.py", line 349, in process_request
# ...

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.9:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[3]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Exploration</code></dd>
#             </dl>
#         </div>
#
#             </div>
# 25/03/24 22:44:33 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
numbers = [[1], [2], [3], [4], [5]]
numbersDF = spark.createDataFrame(numbers, "Id: int")

# %%
numbersDF.show()
# Out:
# +---+
# | Id|
# +---+
# |  1|
# |  2|
# |  3|
# |  4|
# |  5|
# +---+
