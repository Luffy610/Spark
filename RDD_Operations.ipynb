# %%
import findspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("RDDOperations").master("local[*]").getOrCreate()
# Out:
# 25/03/25 23:31:38 WARN Utils: Your hostname, luffy-Latitude-3400 resolves to a loopback address: 127.0.1.1; using 192.168.1.13 instead (on interface wlp0s20f3)
# 25/03/25 23:31:38 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/03/25 23:31:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/03/25 23:31:39 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.13:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>RDDOperations</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc = spark.sparkContext

# %%
sc
# Out:
# <SparkContext master=local[*] appName=RDDOperations>

# %%
numbersRdd = sc.parallelize([1,2,3,4,5])

# %%
numbersRdd.collect()
# Out:
# [1, 2, 3, 4, 5]
